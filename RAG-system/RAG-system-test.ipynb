# %%
import chromadb
import ollama

# %%
print("Rami")
# Out:
# Rami

# %%
print("RAMMMMMMM")
# Out:
# RAMMMMMMM

# %%
print("Test 3jernfoie")
# Out:
# Test 3jernfoie

# %%
print('test 4 ')
# Out:
# test 4

# %%
print("Rami othman40rgoi")
# Out:
# Rami othman40rgoi
