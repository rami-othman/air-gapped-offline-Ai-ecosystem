# %%
import chromadb
import ollama

# %%
print("shahahahah")
# Out:
# shahahahah

# %%
print("RAMMMMMMM")
# Out:
# RAMMMMMMM

# %%
print("Test 3jernfoie")
# Out:
# Test 3jernfoie

# %%
print("shimaa")
# Out:
# shimaa
